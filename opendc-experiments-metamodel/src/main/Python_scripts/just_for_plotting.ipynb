
plt.xlabel('Points')
plt.ylabel('Frequency')
plt.title('Points')
plt.savefig('histogram.pdf')
plt.show()

# %%
time_per_task = [
    [7.2, 8, 20.1], # Alexandru Iosup
    [25, 21, 18], # Animesh Trivedi
    [11.4, 14.4, 9.8], # Jacco van Ossenbruggen
    [11.6, 12.4, 34.5], # Dante Niewenhuis
    [3.9, 7, 7.5], # Sacheendra Talluri
    [4.2, 11.4, 22], # Matthijs Jansen
    [2.7, 13, 7.9], # Krijn Doekemeijer
    [6.9, 6.2, 24.6], # Lennart Schulz
    [13.2, 14.7, 31.4], # Dovydas Vadisius
    [4, 16.5, 26.2] # Alessio Tomei
]

# User-experience assessment scores for each individual
user_experience_assessment = [
    [5, 5, 4], # Alexandru Iosup
    [5, 4, 5], # Animesh Trivedi
    [5, 4, 5], # Jacco van Ossenbruggen
    [5, 5, 5], # Dante Niewenhuis
    [5, 5, 4], # Sacheendra Talluri
    [5, 5, 4], # Matthijs Jansen
    [3, 4, 5], # Krijn Doekemeijer
    [5, 5, 4], # Lennart Schulz
    [4, 4, 5], # Dovydas Vadisius
    [5, 4, 5] # Alessio Tomei
]

time_per_first_task = [7.2, 25, 11.4, 11.6, 3.9, 4.2, 2.7, 6.9, 13.2, 4]
time_per_second_task = [8, 21, 14.4, 12.4, 7, 11.4, 13, 6.2, 14.7, 16.5]
time_per_third_task = [20.1, 18, 9.8, 34.5, 7.5, 22, 7.9, 24.6, 31.4, 26.2]
first_question = [5, 5, 5, 5, 5, 5, 3, 5, 4, 5]
second_question = [5, 4, 4, 5, 5, 5, 4, 5, 4, 4]
third_question = [4, 5, 5, 5, 4, 4, 5, 4, 5, 5]
total_appreciation = [14, 14, 14, 15, 14, 14, 12, 14, 13, 14]

print("Mean total time per task: ", np.mean(time_per_first_task + time_per_second_task + time_per_third_task))
print("Mean total time per task 2: ", (np.mean(time_per_first_task) + np.mean(time_per_second_task) + np.mean(time_per_third_task)) / 3)
print("Mean time per first task: ", np.mean(time_per_first_task))
print("Mean time per second task: ", np.mean(time_per_second_task))
print("Mean time per third task: ", np.mean(time_per_third_task))

print("Mean appreciation for the first question: ", np.mean(first_question))
print("Mean appreciation for the second question: ", np.mean(second_question))
print("Mean appreciation for the third question: ", np.mean(third_question))
print("Mean appreciation for all questions: ", np.mean(total_appreciation) / 3)
print("Median appreciation for the first question: ", np.median(first_question))
print("Median appreciation for the second question: ", np.median(second_question))
print("Median appreciation for the third question: ", np.median(third_question))
print("Median appreciation for all questions: ", np.median(total_appreciation) / 3)

# plot the mean and median values in a table and export as pdf
# Create a table with the mean and median values
# Create a new figure and axes
fig, ax = plt.subplots()

# Round the data to one decimal place
time_per_first_task = np.around(time_per_first_task, 1)
time_per_second_task = np.around(time_per_second_task, 1)
time_per_third_task = np.around(time_per_third_task, 1)
first_question = np.around(first_question, 1)
second_question = np.around(second_question, 1)
third_question = np.around(third_question, 1)
total_appreciation = np.around(total_appreciation, 1)
task_overall_mean = np.mean(time_per_first_task + time_per_second_task + time_per_third_task)
task_overall_median = np.median(time_per_first_task + time_per_second_task + time_per_third_task)
q_overall_mean = np.mean(total_appreciation) / 3
q_overall_median = np.median(total_appreciation) / 3

# Add a table
# Update the table data
table_data = [
    ["", "mean", "median"],
    ["Task 1 (s)", np.around(np.mean(time_per_first_task), 1), np.around(np.median(time_per_first_task), 1)],
    ["Task 2 (s)", np.around(np.mean(time_per_second_task), 1), np.around(np.median(time_per_second_task), 1)],
    ["Task 3 (s)", np.around(np.mean(time_per_third_task), 1), np.around(np.median(time_per_third_task), 1)],
    ["Task Overall (s)", np.around(task_overall_mean, 1), np.around(task_overall_median, 1)],
    ["Q1 (points)", np.around(np.mean(first_question), 1), np.around(np.median(first_question), 1)],
    ["Q2 (points)", np.around(np.mean(second_question), 1), np.around(np.median(second_question), 1)],
    ["Q3 (points)", np.around(np.mean(third_question), 1), np.around(np.median(third_question), 1)],
    ["Q Overall (points)", np.around(q_overall_mean, 1), np.around(q_overall_median, 1)]
]

# Create a new figure and axes
fig, ax = plt.subplots()

# Add a table
table = ax.table(cellText=table_data, loc='center', cellLoc='center', colWidths=[0.1, 0.1, 0.1])

# Hide the axes
ax.axis('off')

# save the plot cropped to content
plt.savefig('mean_median_table.pdf', bbox_inches='tight')
# Show the plot
plt.show()

# save the plot as pdf
# Out:
# Mean total time per task:  13.889999999999999
# Mean total time per task 2:  13.89
# Mean time per first task:  9.010000000000002
# Mean time per second task:  12.459999999999999
# Mean time per third task:  20.2
# Mean appreciation for the first question:  4.7
# Mean appreciation for the second question:  4.5
# Mean appreciation for the third question:  4.6
# Mean appreciation for all questions:  4.6000000000000005
# Median appreciation for the first question:  5.0
# Median appreciation for the second question:  4.5
# Median appreciation for the third question:  5.0
# Median appreciation for all questions:  4.666666666666667

# %%
# plot the time per task, in the same graph, as a boxplot
# plto time per first task, second task, and third task in the boxplot
# Create a list of lists
data = [time_per_first_task, time_per_second_task, time_per_third_task]
# Create the boxplot
# Create the boxplot
plt.boxplot(data, vert=False)

# Set the labels for the y-axis
plt.yticks([1, 2, 3], ['Task 1', 'Task 2', 'Task 3'])

# Set the labels for the x-axis and the title
plt.xlabel('Time (s)')
plt.title('Time per Task')

# Display the plot as pdf
plt.savefig('time_per_task.pdf')

# %%
appreciation1 = np.mean(first_question)
appreciation2 = np.mean(second_question)
appreciation3 = np.mean(third_question)

colors = ["#CE1126" , "#FCD116", "#002B7F"]
data = [appreciation1, appreciation2, appreciation3]
plt.barh(['Q1', 'Q2', 'Q3'], data, color=colors)
plt.xlabel('Quantified appreciation')
plt.title('Average Appreciation per Question')

# Add x ticks
plt.xticks([1, 2, 3, 4, 5])

plt.savefig('average_appreciation_per_question.pdf')
plt.show()

# %%
# plot the time per task, in the same graph, as a vertical histogram
# the x axis should have ticks which vary from 0 to 15 in steps of 5

# Create the histogram
plt.hist(total_appreciation, bins=[10, 11, 12, 13, 14, 15], edgecolor='black')
plt.xticks([0, 5, 10, 15])
# Out:
# ([<matplotlib.axis.XTick at 0x116c79090>,
# ...
#  [Text(0, 0, '0'), Text(5, 0, '5'), Text(10, 0, '10'), Text(15, 0, '15')])
